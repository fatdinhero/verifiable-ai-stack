# %% [markdown]
# # WiseScore Demo (Proof of WiseWork)

# %%
from agentsprotocol.wise_score import compute_wise_score
v = [0.9, 0.8, 0.5, 0.95]
c = [1.0, 2.0, 1.5, 0.5]
r = [5.0, 3.0, 7.0, 2.0]
e = [1.0, 0.9, 0.5, 0.2]
print(compute_wise_score(v, c, r, e))
