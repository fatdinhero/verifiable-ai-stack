# %% [markdown]
# # Meta-Bell Theory — Introduction
#
# Psi measures how far an observed correlation structure sits from the set of local hidden-variable explanations.

# %%
import numpy as np
from agentsprotocol.psi_test import compute_psi
rng = np.random.default_rng(0)
independent = [rng.uniform(0, 0.5, 64).tolist() for _ in range(8)]
colluding = [independent[0]] * 8
print('Psi(independent) =', compute_psi(independent))
print('Psi(colluding)   =', compute_psi(colluding))
